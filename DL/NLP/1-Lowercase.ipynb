# %%
##nlp is a subfield of AI that focuses on enabling computers to understand ,
#  generate and interact using human language 
##it allow machines to understand text or speech 
## analyze sentiment 
#extract keywords 
#translate between languages 
## summarize or generate text

# %%
##text preprocessing
##lowercase
##punctuation
##stopwords
##stemming
##lemmatization
##tokenization
##NER - named entity recognition
##POS - part of speech

# %%
##text to numbers(vectors) --word embeddings 
#one hot 
##BOW - bag of words
## tf-idf - term frequency inverse document frequency
## word2vec - word embeddings

# %%
##lowercase - convert to lowercase
#case sensitive
st = "HELLO WORLD"
print(st.lower())
# Out:
# hello world
